# %%
import pandas as pd
import nameutils as nu

# %%
input_lst = [
    '2001_1996_Census.csv', '2001_2003_Census.csv', '2006_2003_Census.csv', '2011_2003_Census.csv', '2011_2013_Census.csv'
]

df_lst = []
for csv in input_lst:
    df = pd.read_csv(csv)
    name = csv.split('.')[0]
    df.name = name
    #nu.rename_cols(df)
    df_lst.append(df)

res = pd.concat(df_lst, join='inner', ignore_index=True, sort=False)
res.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1563 entries, 0 to 1562
# Data columns (total 80 columns):
#  #   Column                                                           Non-Null Count  Dtype
# ---  ------                                                           --------------  -----
#  0   Year                                                             1563 non-null   int64
#  1   RO Year                                                          1563 non-null   int64
#  2   FED Id                                                           1563 non-null   int64
#  3   FED Name                                                         1563 non-null   object
#  4   population age 0-4                                               1563 non-null   int64
#  5   population age 5-9                                               1563 non-null   int64
#  6   population age 10-14 years                                       1563 non-null   int64
#  7   population age 15-17                                             1563 non-null   int64
#  8   population age 18-19                                             1563 non-null   int64
#  9   population age 20-24                                             1563 non-null   int64
#  10  population age 25-29                                             1563 non-null   int64
#  11  population age 30-34                                             1563 non-null   int64
#  12  population age 35-39                                             1563 non-null   int64
#  13  population age 40-44                                             1563 non-null   int64
#  14  population age 45-49                                             1563 non-null   int64
#  15  population age 50-54                                             1563 non-null   int64
#  16  population age 55-59                                             1563 non-null   int64
#  17  population age 60-64                                             1563 non-null   int64
#  18  population age 70-74                                             1563 non-null   int64
#  19  population age 75-79                                             1563 non-null   int64
#  20  population age 80-84                                             1563 non-null   int64
#  21  population age 85+                                               1563 non-null   int64
#  22  couple families with 1 child                                     1563 non-null   int64
#  23  couple families with 2 children                                  1563 non-null   int64
#  24  couple families with 3 or more children                          1563 non-null   int64
#  25  total num of children at home under 6 years of age               1563 non-null   int64
#  26  total num of children at home age 25+                            1563 non-null   int64
#  27  average num of persons per family                                1563 non-null   float64
#  28  num family that are persons 65+                                  1563 non-null   int64
#  29  private households by household size 1 person                    1563 non-null   int64
#  30  private households by household size 2 persons                   1563 non-null   int64
#  31  private households by household size 3 persons                   1563 non-null   int64
#  32  private households by household size 6 or more persons           1563 non-null   int64
#  33  mother tongue single responses english                           1563 non-null   int64
#  34  mother tongue single responses french                            1563 non-null   int64
#  35  mother tongue multiple responses english and french              1563 non-null   int64
#  36  knowledge of official languages english only                     1563 non-null   int64
#  37  knowledge of official languages french only                      1563 non-null   int64
#  38  knowledge of official languages english and french               1563 non-null   int64
#  39  knowledge of official languages neither english nor french       1563 non-null   int64
#  40  first official language spoken english                           1563 non-null   int64
#  41  first official language spoken french                            1563 non-null   int64
#  42  first official language spoken english and french                1563 non-null   int64
#  43  first official language spoken neither english nor french        1563 non-null   int64
#  44  first official language spoken official language minority num    1563 non-null   int64
#  45  home language spoken single responses english                    1563 non-null   int64
#  46  home language spoken single responses french                     1563 non-null   int64
#  47  population 1 year and over by mobility status 1 year ago movers  1563 non-null   int64
#  48  populati...over by mobility status 1 year ago migrants 250516AB  1563 non-null   int64
#  49  populati...obility status 1 year ago internal migrants E5731743  1563 non-null   int64
#  50  populati... status 1 year ago intraprovincial migrants 9412EDCF  1563 non-null   int64
#  51  populati... status 1 year ago interprovincial migrants F97E9F94  1563 non-null   int64
#  52  populati...obility status 1 year ago external migrants C5DD2868  1563 non-null   int64
#  53  canadian citizenship                                             1563 non-null   int64
#  54  citizenship other than canadian                                  1563 non-null   int64
#  55  born in province of residence                                    1563 non-null   int64
#  56  born outside province of residence                               1563 non-null   int64
#  57  population 15+ by generation status 1st generation               1563 non-null   int64
#  58  population 15+ by generation status 2nd generation               1563 non-null   int64
#  59  population 15+ by generation status 3rd generation and over      1563 non-null   int64
#  60  first nations north american indian single identity              1563 non-null   int64
#  61  métis single identity                                            1563 non-null   int64
#  62  inuit single response identity                                   1563 non-null   int64
#  63  multiple aboriginal responses idenity                            1563 non-null   int64
#  64  aboriginal responses idenity not included elsewhere              1563 non-null   int64
#  65  labour force 15+ by occupation not applicable                    1563 non-null   int64
#  66  labour f...ness finance and administration occupations 2B82C03E  1563 non-null   int64
#  67  labour f...nd applied sciences and related occupations BF041023  1563 non-null   int64
#  68  labour force 15+ by occupation health occupations                1563 non-null   int64
#  69  labour f...pations in art culture recreation and sport E6577C9B  1563 non-null   int64
#  70  labour force 15+ by occupation sales and service occupations     1563 non-null   int64
#  71  population aged 15+ by place of work status worked at home       1563 non-null   int64
#  72  populati... place of work status worked outside canada B2E16A0B  1563 non-null   int64
#  73  populati...e of work status no fixed workplace address 90CEDF61  1563 non-null   int64
#  74  populati... place of work status worked at usual place C99B477F  1563 non-null   int64
#  75  employed...nsportation car truck or van as a passenger 0212B8C0  1563 non-null   int64
#  76  employed...5+ by mode of transportation public transit B18141EA  1563 non-null   int64
#  77  employed labour force 15+ by mode of transportation walked       1563 non-null   int64
#  78  employed labour force 15+ by mode of transportation bicycle      1563 non-null   int64
#  79  employed...15+ by mode of transportation other methods FC108373  1563 non-null   int64
# dtypes: float64(1), int64(78), object(1)
# memory usage: 977.0+ KB

# %%
table_name = "Census"
query = nu.gen_create_table(res, table_name)
print(query)
with open('sql/' + table_name + ".sql", "w") as sql_file:
    sql_file.write(query)
res.to_csv(table_name + '.csv', index=False)
# Out:
# -- drop table Census
#
# create table Census (
# 	"Year" integer,
# 	"RO Year" integer,
# 	"FED Id" integer,
# 	"FED Name" varchar,
# 	"population age 0-4" integer,
# 	"population age 5-9" integer,
# 	"population age 10-14 years" integer,
# 	"population age 15-17" integer,
# 	"population age 18-19" integer,
# 	"population age 20-24" integer,
# 	"population age 25-29" integer,
# 	"population age 30-34" integer,
# 	"population age 35-39" integer,
# 	"population age 40-44" integer,
# 	"population age 45-49" integer,
# 	"population age 50-54" integer,
# 	"population age 55-59" integer,
# 	"population age 60-64" integer,
# 	"population age 70-74" integer,
# 	"population age 75-79" integer,
# 	"population age 80-84" integer,
# 	"population age 85+" integer,
# 	"couple families with 1 child" integer,
# 	"couple families with 2 children" integer,
# 	"couple families with 3 or more children" integer,
# 	"total num of children at home under 6 years of age" integer,
# 	"total num of children at home age 25+" integer,
# 	"average num of persons per family" float,
# 	"num family that are persons 65+" integer,
# 	"private households by household size 1 person" integer,
# 	"private households by household size 2 persons" integer,
# 	"private households by household size 3 persons" integer,
# 	"private households by household size 6 or more persons" integer,
# 	"mother tongue single responses english" integer,
# 	"mother tongue single responses french" integer,
# 	"mother tongue multiple responses english and french" integer,
# 	"knowledge of official languages english only" integer,
# 	"knowledge of official languages french only" integer,
# 	"knowledge of official languages english and french" integer,
# 	"knowledge of official languages neither english nor french" integer,
# 	"first official language spoken english" integer,
# 	"first official language spoken french" integer,
# 	"first official language spoken english and french" integer,
# 	"first official language spoken neither english nor french" integer,
# 	"first official language spoken official language minority num" integer,
# 	"home language spoken single responses english" integer,
# 	"home language spoken single responses french" integer,
# 	"population 1 year and over by mobility status 1 year ago movers" integer,
# 	"populati...over by mobility status 1 year ago migrants 250516AB" integer,
# 	"populati...obility status 1 year ago internal migrants E5731743" integer,
# 	"populati... status 1 year ago intraprovincial migrants 9412EDCF" integer,
# 	"populati... status 1 year ago interprovincial migrants F97E9F94" integer,
# 	"populati...obility status 1 year ago external migrants C5DD2868" integer,
# 	"canadian citizenship" integer,
# 	"citizenship other than canadian" integer,
# 	"born in province of residence" integer,
# 	"born outside province of residence" integer,
# 	"population 15+ by generation status 1st generation" integer,
# 	"population 15+ by generation status 2nd generation" integer,
# 	"population 15+ by generation status 3rd generation and over" integer,
# 	"first nations north american indian single identity" integer,
# 	"métis single identity" integer,
# 	"inuit single response identity" integer,
# 	"multiple aboriginal responses idenity" integer,
# 	"aboriginal responses idenity not included elsewhere" integer,
# 	"labour force 15+ by occupation not applicable" integer,
# 	"labour f...ness finance and administration occupations 2B82C03E" integer,
# 	"labour f...nd applied sciences and related occupations BF041023" integer,
# 	"labour force 15+ by occupation health occupations" integer,
# 	"labour f...pations in art culture recreation and sport E6577C9B" integer,
# 	"labour force 15+ by occupation sales and service occupations" integer,
# 	"population aged 15+ by place of work status worked at home" integer,
# 	"populati... place of work status worked outside canada B2E16A0B" integer,
# 	"populati...e of work status no fixed workplace address 90CEDF61" integer,
# 	"populati... place of work status worked at usual place C99B477F" integer,
# 	"employed...nsportation car truck or van as a passenger 0212B8C0" integer,
# 	"employed...5+ by mode of transportation public transit B18141EA" integer,
# 	"employed labour force 15+ by mode of transportation walked" integer,
# 	"employed labour force 15+ by mode of transportation bicycle" integer,
# 	"employed...15+ by mode of transportation other methods FC108373" integer
# );
